# %%
import pandas as pd
import numpy as np
from sklearn.utils import shuffle
import seaborn as sns


from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.dummy import DummyClassifier
from sklearn.model_selection import GridSearchCV
from sklearn import svm

# %% [markdown]
# ### Описание:
#
# Попытка обучения леса и svm на синтетических данных.
# Данные два круга один внури другого.

# %%
#построение окружности

# %%
z1 = pd.DataFrame(np.arange(360), columns=['angle'])

# %%
z1
# Out:
#      angle
# 0        0
# 1        1
# 2        2
# 3        3
# 4        4
# ..     ...
# 355    355
# 356    356
# 357    357
# 358    358
# 359    359
#
# [360 rows x 1 columns]

# %%
z1['x'] = z1['angle'].apply(lambda x: 100*np.sin(np.pi*2*x/360) + np.random.uniform(-20,20))

# %%
z1
# Out:
#      angle          x
# 0        0  14.271693
# 1        1  12.978497
# 2        2  10.207909
# 3        3 -11.270046
# 4        4  22.291561
# ..     ...        ...
# 355    355 -24.817254
# 356    356  -1.963407
# 357    357 -18.139790
# 358    358   6.690307
# 359    359  16.976288
#
# [360 rows x 2 columns]

# %%
z1.plot(x='angle', y='x', kind='scatter', grid=True, alpha=1)
# Out:
# <AxesSubplot:xlabel='angle', ylabel='x'>

# %%
np.sin(np.pi)
# Out:
# 1.2246467991473532e-16

# %%
z1['y'] = z1['angle'].apply(lambda x: 100*np.cos(np.pi*2*x/360) + np.random.uniform(-20,20))

# %%
z1.plot(x='angle', y='y', kind='scatter', grid=True, alpha=1)
# Out:
# <AxesSubplot:xlabel='angle', ylabel='y'>

# %%
z1.plot(x='x', y='y', kind='scatter', grid=True, alpha=1, figsize=(6,6))
# Out:
# <AxesSubplot:xlabel='x', ylabel='y'>

# %%
z1['t'] = 0

# %%
z1
# Out:
#      angle          x           y  t
# 0        0  14.271693   84.402933  0
# 1        1  12.978497   80.684495  0
# 2        2  10.207909   83.828274  0
# 3        3 -11.270046   97.986595  0
# 4        4  22.291561   94.302689  0
# ..     ...        ...         ... ..
# 355    355 -24.817254  116.042843  0
# 356    356  -1.963407   82.824738  0
# 357    357 -18.139790   98.591453  0
# 358    358   6.690307   97.785884  0
# 359    359  16.976288  109.181597  0
#
# [360 rows x 4 columns]

# %%
#круг для данных типа 1

# %%
z2 = pd.DataFrame(np.arange(360), columns=['angle'])

# %%
z2['x'] = z2['angle'].apply(lambda x: 75*np.sin(np.pi*2*x/360) + np.random.uniform(-20,20))

# %%
z2['y'] = z2['angle'].apply(lambda x: 75*np.cos(np.pi*2*x/360) + np.random.uniform(-20,20))

# %%
z2['t'] = 1

# %%
z2.plot(x='x', y='y', kind='scatter', grid=True, alpha=1, figsize=(6,6))
# Out:
# <AxesSubplot:xlabel='x', ylabel='y'>

# %%
z33 = pd.concat([z1, z2]).reset_index().drop('index', axis=1)

# %%
z33
# Out:
#      angle          x          y  t
# 0        0  14.271693  84.402933  0
# 1        1  12.978497  80.684495  0
# 2        2  10.207909  83.828274  0
# 3        3 -11.270046  97.986595  0
# 4        4  22.291561  94.302689  0
# ..     ...        ...        ... ..
# 715    355 -13.171419  88.386765  1
# 716    356  -0.578292  76.582635  1
# 717    357   2.073033  74.306784  1
# 718    358  16.803493  66.476768  1
# 719    359  -9.007150  63.701243  1
#
# [720 rows x 4 columns]

# %%
z33 = shuffle(z33, random_state=12345).reset_index()

# %%
z33
# Out:
#      index  angle          x          y  t
# 0      589    229 -55.284026 -37.019681  1
# 1      578    218 -38.309720 -74.934110  1
# 2      616    256 -90.396436 -18.441898  1
# 3      682    322 -46.532671  50.099099  1
# 4      557    197 -34.882942 -82.251254  1
# ..     ...    ...        ...        ... ..
# 715    420     60  83.046067  22.612246  1
# 716    129    129  87.870105 -48.431667  0
# 717    285    285 -92.379575   9.197288  0
# 718    485    125  77.292010 -48.299363  1
# 719    482    122  63.659830 -39.943719  1
#
# [720 rows x 5 columns]

# %%
sns.set_style("whitegrid")
sns.scatterplot(data=z33, x='x', y='y', hue='t')
# Out:
# <AxesSubplot:xlabel='x', ylabel='y'>

# %%
#test

# %%
target = z33['t']

# %%
target.shape
# Out:
# (720,)

# %%
features = z33[['x', 'y']]

# %%
features.shape
# Out:
# (720, 2)

# %% [markdown]
# ### модель - случайный лес

# %%
#логарифмическая сетка параметров для модели Случайный Лес
params = {
    'n_estimators':[40,80], 
    'max_depth':[16, 32], 
    'min_samples_split':[2], 
    'min_samples_leaf':[2]
}

# %%
rf = RandomForestClassifier(random_state=12345, class_weight='balanced')

# %%
clf = GridSearchCV(rf, params, scoring='f1', cv=5, n_jobs=-1)

# %%
# %%time
clf.fit(features, target)
# Out:
# CPU times: user 251 ms, sys: 72.7 ms, total: 324 ms
# Wall time: 6.52 s
# GridSearchCV(cv=5,
#              estimator=RandomForestClassifier(class_weight='balanced',
#                                               random_state=12345),
#              n_jobs=-1,
#              param_grid={'max_depth': [16, 32], 'min_samples_leaf': [2],
#                          'min_samples_split': [2], 'n_estimators': [40, 80]},
#              scoring='f1')

# %%
clf.best_score_
# Out:
# 0.847497883989177

# %%
clf.best_params_
# Out:
# {'max_depth': 32,
#  'min_samples_leaf': 2,
#  'min_samples_split': 2,
#  'n_estimators': 40}

# %% [markdown]
# ### модель - SVM

# %%
C_range = np.logspace(-2, 4, 7)#13)
gamma_range = np.logspace(-4, 2, 7)#13)
param_grid = dict(gamma=gamma_range, C=C_range)

# %%
regr = svm.SVC()

# %%
clf = GridSearchCV(regr, param_grid=param_grid, cv=5, n_jobs=-1)

# %%
# %%time
clf.fit(features, target)
# Out:
# CPU times: user 361 ms, sys: 22.6 ms, total: 383 ms
# Wall time: 15.2 s
# GridSearchCV(cv=5, estimator=SVC(), n_jobs=-1,
#              param_grid={'C': array([1.e-02, 1.e-01, 1.e+00, 1.e+01, 1.e+02, 1.e+03, 1.e+04]),
#                          'gamma': array([1.e-04, 1.e-03, 1.e-02, 1.e-01, 1.e+00, 1.e+01, 1.e+02])})

# %%
print(
    "The best parameters are %s with a score of %0.2f"
    % (clf.best_params_, clf.best_score_)
)
# Out:
# The best parameters are {'C': 10.0, 'gamma': 0.0001} with a score of 0.85

# %% [markdown]
# ### Ну и для Гитхаба пару строк

# %%
np.sin(30)
# Out:
# -0.9880316240928618
