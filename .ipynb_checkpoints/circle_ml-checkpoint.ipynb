# %%
import pandas as pd
import numpy as np
from sklearn.utils import shuffle
import seaborn as sns


from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.dummy import DummyClassifier
from sklearn.model_selection import GridSearchCV
from sklearn import svm

# %%
#построение окружности

# %%
z1 = pd.DataFrame(np.arange(360), columns=['angle'])

# %%
z1
# Out:
#      angle
# 0        0
# 1        1
# 2        2
# 3        3
# 4        4
# ..     ...
# 355    355
# 356    356
# 357    357
# 358    358
# 359    359
#
# [360 rows x 1 columns]

# %%
z1['x'] = z1['angle'].apply(lambda x: 100*np.sin(np.pi*2*x/360) + np.random.uniform(-10,10))

# %%
z1
# Out:
#      angle          x
# 0        0   7.438898
# 1        1   6.758801
# 2        2  -0.589091
# 3        3   3.262158
# 4        4   5.017422
# ..     ...        ...
# 355    355 -16.821565
# 356    356 -16.736305
# 357    357  -0.473716
# 358    358  -1.378404
# 359    359  -9.890864
#
# [360 rows x 2 columns]

# %%
z1.plot(x='angle', y='x', kind='scatter', grid=True, alpha=1)
# Out:
# <AxesSubplot:xlabel='angle', ylabel='x'>

# %%
np.sin(np.pi)
# Out:
# 1.2246467991473532e-16

# %%
z1['y'] = z1['angle'].apply(lambda x: 100*np.cos(np.pi*2*x/360) + np.random.uniform(-10,10))

# %%
z1.plot(x='angle', y='y', kind='scatter', grid=True, alpha=1)
# Out:
# <AxesSubplot:xlabel='angle', ylabel='y'>

# %%
z1.plot(x='x', y='y', kind='scatter', grid=True, alpha=1, figsize=(6,6))
# Out:
# <AxesSubplot:xlabel='x', ylabel='y'>

# %%
z1['t'] = 0

# %%
z1
# Out:
#      angle          x           y  t
# 0        0   7.438898  103.508846  0
# 1        1   6.758801  109.247946  0
# 2        2  -0.589091  105.208503  0
# 3        3   3.262158  104.851732  0
# 4        4   5.017422  103.964320  0
# ..     ...        ...         ... ..
# 355    355 -16.821565   94.622124  0
# 356    356 -16.736305  101.820998  0
# 357    357  -0.473716  100.529070  0
# 358    358  -1.378404  107.503144  0
# 359    359  -9.890864  105.860298  0
#
# [360 rows x 4 columns]

# %%
#круг для данных типа 1

# %%
z2 = pd.DataFrame(np.arange(360), columns=['angle'])

# %%
z2['x'] = z2['angle'].apply(lambda x: 75*np.sin(np.pi*2*x/360) + np.random.uniform(-15,15))

# %%
z2['y'] = z2['angle'].apply(lambda x: 75*np.cos(np.pi*2*x/360) + np.random.uniform(-15,15))

# %%
z2['t'] = 1

# %%
z2.plot(x='x', y='y', kind='scatter', grid=True, alpha=1, figsize=(6,6))
# Out:
# <AxesSubplot:xlabel='x', ylabel='y'>

# %%
z33 = pd.concat([z1, z2]).reset_index().drop('index', axis=1)

# %%
z33
# Out:
#      angle          x           y  t
# 0        0   7.438898  103.508846  0
# 1        1   6.758801  109.247946  0
# 2        2  -0.589091  105.208503  0
# 3        3   3.262158  104.851732  0
# 4        4   5.017422  103.964320  0
# ..     ...        ...         ... ..
# 715    355 -16.155973   69.968675  1
# 716    356   1.108508   68.174745  1
# 717    357 -13.052845   83.116919  1
# 718    358 -11.198476   73.798290  1
# 719    359  -3.088329   69.510268  1
#
# [720 rows x 4 columns]

# %%
z33 = shuffle(z33, random_state=12345).reset_index()

# %%
z33
# Out:
#      index  angle          x          y  t
# 0      589    229 -61.983685 -50.414360  1
# 1      578    218 -37.052098 -59.224543  1
# 2      616    256 -68.335554 -22.826146  1
# 3      682    322 -40.085336  60.382781  1
# 4      557    197 -15.065280 -73.207321  1
# ..     ...    ...        ...        ... ..
# 715    420     60  55.090475  46.629933  1
# 716    129    129  75.271027 -58.929109  0
# 717    285    285 -89.160535  24.658339  0
# 718    485    125  70.109453 -38.206790  1
# 719    482    122  70.278341 -41.989360  1
#
# [720 rows x 5 columns]

# %%
sns.set_style("whitegrid")
sns.scatterplot(data=z33, x='x', y='y', hue='t')
# Out:
# <AxesSubplot:xlabel='x', ylabel='y'>

# %%
#test

# %%
target = z33['t']

# %%
target.shape
# Out:
# (720,)

# %%
features = z33[['x', 'y']]

# %%
features.shape
# Out:
# (720, 2)

# %% [markdown]
# ### модель - случайный лес

# %%
#логарифмическая сетка параметров для модели Случайный Лес
params = {
    'n_estimators':[40,80], 
    'max_depth':[16, 32], 
    'min_samples_split':[2], 
    'min_samples_leaf':[2]
}

# %%
rf = RandomForestClassifier(random_state=12345, class_weight='balanced')

# %%
clf = GridSearchCV(rf, params, scoring='f1', cv=5, n_jobs=-1)

# %%
# %%time
clf.fit(features, target)
# Out:
# CPU times: user 401 ms, sys: 76.7 ms, total: 478 ms
# Wall time: 7.14 s
# GridSearchCV(cv=5,
#              estimator=RandomForestClassifier(class_weight='balanced',
#                                               random_state=12345),
#              n_jobs=-1,
#              param_grid={'max_depth': [16, 32], 'min_samples_leaf': [2],
#                          'min_samples_split': [2], 'n_estimators': [40, 80]},
#              scoring='f1')

# %%
clf.best_score_
# Out:
# 0.9682934446019

# %%
clf.best_params_
# Out:
# {'max_depth': 16,
#  'min_samples_leaf': 2,
#  'min_samples_split': 2,
#  'n_estimators': 80}

# %% [markdown]
# ### модель - SVM

# %%
C_range = np.logspace(-2, 4, 7)#13)
gamma_range = np.logspace(-4, 2, 7)#13)
param_grid = dict(gamma=gamma_range, C=C_range)

# %%
regr = svm.SVC()

# %%
clf = GridSearchCV(regr, param_grid=param_grid, cv=5, n_jobs=-1)

# %%
# %%time
clf.fit(features, target)
# Out:
# CPU times: user 350 ms, sys: 21.6 ms, total: 372 ms
# Wall time: 10.7 s
# GridSearchCV(cv=5, estimator=SVC(), n_jobs=-1,
#              param_grid={'C': array([1.e-02, 1.e-01, 1.e+00, 1.e+01, 1.e+02, 1.e+03, 1.e+04]),
#                          'gamma': array([1.e-04, 1.e-03, 1.e-02, 1.e-01, 1.e+00, 1.e+01, 1.e+02])})

# %%
print(
    "The best parameters are %s with a score of %0.2f"
    % (clf.best_params_, clf.best_score_)
)
# Out:
# The best parameters are {'C': 1.0, 'gamma': 0.0001} with a score of 1.00
